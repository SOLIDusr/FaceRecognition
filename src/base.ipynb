# %%
# %pip install deepface
# %pip install scikit-learn
# %pip install tqdm
# %pip install numpy
# %pip install pillow
# %pip install matplotlib
# Out:
# Requirement already satisfied: deepface in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (0.0.92)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests>=2.27.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (2.32.3)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (2.2.2)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (4.66.4)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (10.3.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (4.10.0.84)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (2.17.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (3.4.1)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (3.0.3)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (0.6.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from deepface) (22.0.0)
# Requirement already satisfied: six in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from Flask>=1.1.2->deepface) (1.8.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.3)
# Requirement already satisfied: filelock in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from gdown>=3.10.1->deepface) (3.15.1)
# Requirement already satisfied: packaging in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from gunicorn>=20.1.0->deepface) (24.1)
# Requirement already satisfied: absl-py in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from keras>=2.2.0->deepface) (2.1.0)
# Requirement already satisfied: rich in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from keras>=2.2.0->deepface) (13.7.1)
# Requirement already satisfied: namex in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from keras>=2.2.0->deepface) (3.11.0)
# Requirement already satisfied: optree in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from keras>=2.2.0->deepface) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from keras>=2.2.0->deepface) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23.4->deepface) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23.4->deepface) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23.4->deepface) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27.1->deepface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27.1->deepface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27.1->deepface) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.27.1->deepface) (2024.6.2)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.17.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (70.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (2.17.0)
# Requirement already satisfied: colorama in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=2.2.0->deepface) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.18.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (0.43.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: scikit-learn in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (4.66.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: colorama in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: numpy in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pillow in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (10.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\naromori\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from deepface import DeepFace as dface
import os
from glob import glob
from sklearn.metrics import accuracy_score,  top_k_accuracy_score
from tqdm import tqdm
# Out:
# WARNING:tensorflow:From c:\Users\NaroMori\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def analyzeEmotion(imagePath: str) -> str | None:
    try:
        result = dface.analyze(img_path=imagePath, actions=["emotion"], enforce_detection=False)
        return result[0]
    except Exception as e:
        print(f"Error processing image {imagePath}: {e}")
        return None

# %%
def getEmotionFromPath(imagePath: str) -> str:
    return imagePath.split("\\")[1]

# %%
def checkGuess(imagePath: str, result: str) -> bool:
    emotion = getEmotionFromPath(imagePath=imagePath)
    return emotion == result.lower()

# %%
def loadImages(imgDirectory: str, fileFormat = ".jpg") -> list[str]:
    images = [y for x in os.walk(imgDirectory) for y in glob(os.path.join(x[0], f'*{fileFormat}'))]
    if len(images) == 0:
        raise FileNotFoundError(f"No photos found in {imgDirectory} or directory doesn't exist")
    return images

# %%
imgDirectory = "../babyset"
images = loadImages(imgDirectory=imgDirectory)

correctGuesses, incorrectGuesses, faceNotFound = 0, 0, 0

yTrue = []
yPredProbs = []

for image in tqdm(images):
    result = analyzeEmotion(image)
    emotionResult = result["emotion"]
    dominantEmotion = result.get("dominant_emotion")
    if dominantEmotion is None:
        faceNotFound += 1
        continue
    yTrue.append(getEmotionFromPath(image))
    yPredProbs.append(list(emotionResult.values()))

    if checkGuess(image, dominantEmotion):
        correctGuesses += 1
    else:
        incorrectGuesses += 1
# Out:
#   0%|          | 0/688 [00:00<?, ?it/s]
# 100%|██████████| 688/688 [03:09<00:00,  3.64it/s]

# %%
print(f"Correct {correctGuesses} \nIncorrect {incorrectGuesses} \nFaces not found {faceNotFound}")

print(f"Top-1 accuracy - {round(top_k_accuracy_score(y_true=yTrue, y_score=yPredProbs, k=1), 2)}\n"+
      f"Top-3 accuracy - {round(top_k_accuracy_score(y_true=yTrue, y_score=yPredProbs, k=3), 2)}\n"+
      f"Top-5 accuracy - {round(top_k_accuracy_score(y_true=yTrue, y_score=yPredProbs, k=5), 2)}")
# Out:
# Correct 348
# Incorrect 340
# Faces not found 0
# Top-1 accuracy - 0.32
# Top-3 accuracy - 0.59
# Top-5 accuracy - 0.75

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image


for i in range(5):
    imagePath = random.choice(images)
    image = np.asarray(Image.open(imagePath))
    plt.imshow(image)
    result = analyzeEmotion(imagePath=imagePath)["dominant_emotion"]
    plt.text(10, 10, result, bbox=dict(facecolor='white', alpha=0.5))
    plt.show()
